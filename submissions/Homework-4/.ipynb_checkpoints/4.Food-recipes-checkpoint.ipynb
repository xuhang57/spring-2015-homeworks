# %% [markdown]
# (In order to load the stylesheet of this notebook, execute the last code cell in this notebook)

# %% [markdown]
# # Clustering food recipes from around the world

# %% [markdown]
# In this assignment, you are expected to hierarchically cluster food recipes. We will be using YY Ahn's dataset "[Recipe datasets with cuisines](http://yongyeol.com/data/scirep-cuisines-detail.zip)", which for each recipe provides a list of ingredients and the country of origin, scraped from popular recipe websites. He also provides an [ingredient and compounds dataset](http://yongyeol.com/data/ingr_comp.zip), which you could potentially also make use of, if you find it interesting.
#
# You will be graded as follow:
# * Data parsing and representation **(20 pts)**
# * Clustering **(30 pts)**
# * Visualization **(30 pts)**
# * Short (datailed) analysis of specific cluster **(20 pts)**
#
# ---------------------------

# %%
# Web scraping
#     1. Retrieve webpages:
#         . wget, curl: command line tool for transferring
#             data with URL syntax
#         . Fully-fledged web browsers
#             Selenium (web browser automation)
#     2. Parse and extract information form the html
#         . html/json parsers

# For retrieve Webpages:
#     Either 1. Embed command line tools (wget or curl) in python code:
            # out_file = 'test.html'
            # url = 'www.xxx.com'
            # cmd = 'curl -L -m 2 "' + url + '" >'  + ofile
            # os.system(cmd)

#     or    2. Use a python network-access libraries
#         . Urllib, Request, pycurl,etc.
#             import urllib2
#             response = urllib2.urlopen('http://www.tripadvisor.com/Hotels-g60745-Boston_Massachusetts-Hotels.html')
#             html = response.read()

import numpy as np
import scipy.cluster.hierarchy as cl_hier
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
# %matplotlib inline

#Parse data to create a dictionary of dictionaries where the key to the big dictionary is a 
# country of the world, the value is another dictionary. The key to the inner dictinoary is an 
# ingredient and its value is how many recipes in that particular country use that ingredient. 

countries = {}
ingredients = []
# print countries.keys()
with open('allr_recipes.txt') as f:
    for line in f:
        row = line.split('\t')
        row[len(row) - 1] = row[len(row) - 1][:-1]
        Ckeys = row[0]
        row.remove(Ckeys)
        if Ckeys in countries.keys():
            for i in range(0, len(row)):
                Ckey_i = row[i]
                if Ckey_i in country.keys():
                    country[Ckey_i] += 1
                else:
                    if Ckey_i not in ingredients:
                        ingredients.append(Ckey_i)
                    country[Ckey_i] = 1
        else:
            country = {}
            countries[Ckeys] = {}
            for i in range(0, len(row)):
                Ckey_i = row[i]
                if Ckey_i not in ingredients:
                    ingredients.append(Ckey_i)
                country[Ckey_i] = 1
        countries[Ckeys] = country
f.close()

print countries
print ingredients

#Parse data to create a dictionary of dictionaries where the key to the big dictionary is a 
# region of the world, the value is another dictionary. The key to the inner dictinoary is an 
# ingredient and its value is how many recipes in that particular region use that ingredient. 

regions = {}
locations = {}
with open('map.txt') as f:
    for line in f:
        row = line.split('\t')
        row[len(row) - 1] = row[len(row) - 1][:-1]
        locations[row[0]] = row[1]


for country in countries.keys():
    region = locations[country]
    if region not in regions.keys():
        regions[region] = {}
    country = countries[country]
    for Ck in country.keys():
        if Ck not in regions[region].keys():
            regions[region][Ck] = country[Ck]
        else:
            regions[region][Ck] += country[Ck]
f.close()

print regions
# Out:
_pork': 3, 'buttermilk': 16, 'beer': 8, 'horseradish': 5, 'beet': 2, 'pork_sausage': 16, 'crab': 14, 'basil': 47, 'vegetable_oil': 145, 'brussels_sprout': 2, 'smoked_salmon': 2, 'fish': 12, 'kiwi': 1, 'butter': 295, 'green_bell_pepper': 41, 'brassica': 1, 'mushroom': 54, 'shallot': 4, 'red_wine': 12, 'squash': 5, 'orange': 18, 'pecan': 16, 'roasted_beef': 6, 'cream_cheese': 38, 'hazelnut': 4, 'olive': 8, 'palm': 1, 'apricot': 2, 'vanilla': 138, 'parmesan_cheese': 39, 'banana': 16, 'strawberry': 15, 'seed': 21, 'turnip': 5, 'root': 1, 'cognac': 1, 'cane_molasses': 159, 'olive_oil': 96, 'coconut': 28, 'squid': 1, 'whiskey': 2, 'ginger': 47, 'yam': 1, 'honey': 24, 'carrot': 57, 'cacao': 1, 'mint': 5, 'red_kidney_bean': 1, 'cream': 117, 'lamb': 4, 'currant': 1, 'date': 9, 'peach': 6, 'rhubarb': 7, 'starch': 49, 'cottage_cheese': 7, 'oat': 26, 'macaroni': 42, 'sesame_seed': 9, 'vegetable': 16, 'sherry': 6, 'leek': 4, 'bell_pepper': 78, 'fenugreek': 23, 'papaya': 3, 'mustard': 66, 'cardamom': 3, 'blue_cheese': 3, 'salmon': 12, 'gelatin': 14, 'mace': 1, 'fruit': 4, 'cucumber': 21, 'pimento': 2, 'mozzarella_cheese': 21, 'lemon': 30, 'tuna': 4, 'watercress': 1, 'broccoli': 15, 'brown_rice': 2, 'lime_juice': 17, 'tomato': 132, 'caraway': 1, 'roasted_peanut': 1, 'potato': 73, 'feta_cheese': 13, 'gin': 3, 'meat': 7, 'mango': 5, 'veal': 2, 'wheat_bread': 4, 'pineapple': 13, 'corn_flake': 4, 'wine': 3, 'egg': 274, 'turmeric': 30}, 'Turkey': {'cane_molasses': 1, 'dill': 2, 'olive_oil': 6, 'carrot': 1, 'chicken': 5, 'mint': 2, 'milk': 3, 'lamb': 1, 'lemon': 1, 'beef': 4, 'cayenne': 2, 'parsley': 3, 'walnut': 2, 'milk_fat': 1, 'macaroni': 1, 'yogurt': 6, 'vegetable_oil': 1, ...
# ['egg', 'yeast', 'wheat', 'milk', 'lard', 'pork', 'carrot', 'pea', 'onion', 'potato', 'maple_syrup', 'almond', 'honey', 'oat', 'date', 'vegetable_oil', 'whole_grain_wheat_flour', 'butter', 'lovage', 'clam', 'thyme', 'black_pepper', 'parsley', 'ginger', 'bay', 'celery', 'cinnamon', 'mustard', 'cane_molasses', 'raisin', 'cream', 'asparagus', 'olive_oil', 'pepper', 'garlic', 'tomato', 'cilantro', 'tea', 'jasmine', 'vegetable', 'brown_rice', 'lemon_juice', 'soy_sauce', 'white_wine', 'chicken', 'vanilla', 'rice', 'mushroom', 'chicken_broth', 'basil', 'porcini', 'mozzarella_cheese', 'tuna', 'lemon', 'beef', 'fish', 'cocoa', 'green_bell_pepper', 'oregano', 'rosemary', 'coffee', 'banana', 'squash', 'egg_noodle', 'bell_pepper', 'cheddar_cheese', 'broccoli', 'cayenne', 'scallion', 'lettuce', 'cucumber', 'cream_cheese', 'melon', 'cranberry', 'peanut', 'nut', 'chickpea', 'yogurt', 'bread', 'tabasco_pepper', 'cod', 'bacon', 'pimento', 'black_tea', 'grapefruit', 'orange_juice', 'pineapple', 'vinegar', 'sesame_oil', 'sake', 'sesame_seed', 'soybean', 'thai_pepper', 'nutmeg', 'pumpkin', 'roasted_beef', 'cottage_cheese', 'red_wine', 'salmon', 'coriander', 'coconut', 'fenugreek', 'starch', 'cumin', 'turmeric', 'celery_oil', 'corn', 'cheese', 'port_wine', 'pecan', 'chive', 'apple', 'seed', 'tamarind', 'tarragon', 'sweet_potato', 'black_bean', 'pork_sausage', 'berry', 'swiss_cheese', 'lobster', 'parmesan_cheese', 'crab', 'chicken_liver', 'veal', 'macaroni', 'shiitake', 'wine', 'buttermilk', 'avocado', 'fennel', 'orange_peel', 'orange', 'walnut', 'grape', 'fruit', 'papaya', 'peach', 'hazelnut', 'shallot', 'lime_juice', 'grape_juice', 'cherry', 'blue_cheese', 'cabbage', 'strawberry', 'potato_chip', 'mango', 'ham', 'smoke', 'kidney_bean', 'feta_cheese', 'marjoram', 'meat', 'rhubarb', 'blackberry', 'raspberry', 'peanut_butter', 'barley', 'blueberry', 'peppermint', 'milk_fat', 'oyster', 'dill', 'beet', 'cured_pork', 'squid', 'turkey', 'sage', 'lamb', 'goat_cheese', 'mint', 'mace', 'sherry', 'corn_flake', 'brandy', 'bitter_orange', 'beer', 'cacao', 'bean', 'gelatin', 'lime', 'beef_broth', 'zucchini', 'caraway', 'red_kidney_bean', 'cider', 'rum', 'brussels_sprout', 'olive', 'horseradish', 'shrimp', 'cauliflower', 'parsnip', 'roasted_peanut', 'lentil', 'cognac', 'plum', 'rye_flour', 'radish', 'whiskey', 'sassafras', 'turnip', 'peanut_oil', 'cashew', 'mandarin', 'gin', 'kale', 'tomato_juice', 'black_mustard_seed_oil', 'pear', 'kiwi', 'savory', 'wheat_bread', 'white_bread', 'scallop', 'haddock', 'carob', 'root', 'leek', 'nectarine', 'popcorn', 'citrus', 'smoked_salmon', 'liver', 'rutabaga', 'juniper_berry', 'lima_bean', 'currant', 'brassica', 'cereal', 'cardamom', 'lemon_peel', 'rye_bread', 'sauerkraut', 'pistachio', 'lavender', 'apricot', 'malt', 'roasted_sesame_seed', 'roasted_meat', 'romano_cheese', 'yam', 'palm', 'artichoke', 'watercress', 'coconut_oil', 'okra', 'saffron', 'smoked_sausage', 'cassava', 'guava', 'corn_grit', 'roasted_pork', 'anise', 'lime_peel_oil', 'rose', 'sunflower_oil', 'prawn', 'anise_seed', 'star_anise', 'macadamia_nut', 'provolone_cheese', 'quince', 'fig', 'cherry_brandy', 'mandarin_peel', 'apple_brandy', 'camembert_cheese', 'mussel', 'caviar', 'chicory', 'bourbon_whiskey', 'endive', 'bone_oil', 'tequila', 'roquefort_cheese', 'orange_flower', 'truffle', 'catfish', 'leaf', 'chinese_cabbage', 'seaweed', 'sumac', 'buckwheat', 'peppermint_oil', 'hop', 'licorice', 'tangerine', 'sour_cherry', 'elderberry', 'passion_fruit', 'octopus', 'watermelon', 'lingonberry', 'violet', 'galanga', 'frankfurter', 'sour_milk', 'ouzo', 'chervil', 'balm', 'beef_liver', 'mung_bean', 'green_tea', 'wasabi', 'litchi', 'lemongrass', 'huckleberry', 'champagne_wine', 'pear_brandy', 'roasted_hazelnut', 'prickly_pear', 'bartlett_pear', 'cabernet_sauvignon_wine', 'wood', 'munster_cheese', 'bergamot', 'mate', 'concord_grape', 'salmon_roe', 'flower', 'oatmeal', 'kohlrabi', 'kumquat', 'jasmine_tea', 'chayote', 'condiment', 'pork_liver', 'black_raspberry', 'lilac_flower ...
# {'NorthernEuropean': {'orange_peel': 1, 'lemon_juice': 3, 'cream_cheese': 1, 'orange_juice': 2, 'sage': 1, 'white_wine': 1, 'fennel': 2, 'chicken': 2, 'milk': 42, 'ham': 4, 'cherry': 3, 'walnut': 7, 'celery': 2, 'blueberry': 1, 'orange': 12, 'rice': 4, 'coffee': 2, 'yeast': 20, 'citrus': 2, 'cinnamon': 29, 'black_pepper': 12, 'bean': 1, 'bread': 8, 'coriander': 1, 'bourbon_whiskey': 1, 'meat': 1, 'onion': 17, 'chicken_broth': 1, 'cumin': 2, 'nutmeg': 9, 'beef_broth': 2, 'pork': 6, 'celery_oil': 1, 'fish': 4, 'almond': 36, 'bacon': 2, 'currant': 1, 'whole_grain_wheat_flour': 3, 'strawberry': 1, 'milk_fat': 1, 'rye_flour': 9, 'lard': 11, 'yogurt': 1, 'pea': 2, 'pepper': 12, 'wheat': 118, 'rum': 2, 'pear': 3, 'corn': 7, 'raspberry': 1, 'vinegar': 9, 'lingonberry': 2, 'plum': 1, 'raisin': 11, 'shrimp': 1, 'bell_pepper': 2, 'smoke': 2, 'blue_cheese': 1, 'chive': 1, 'cucumber': 2, 'cheddar_cheese': 1, 'cheese': 1, 'apple': 4, 'dill': 5, 'tabasco_pepper': 1, 'cocoa': 6, 'lettuce': 1, 'tamarind': 1, 'rutabaga': 1, 'beef': 8, 'romano_cheese': 1, 'caviar': 1, 'parsley': 7, 'bitter_orange': 1, 'scallion': 1, 'buttermilk': 7, 'beet': 2, 'vegetable_oil': 9, 'nut': 1, 'tomato': 3, 'green_bell_pepper': 1, 'mushroom': 1, 'shallot': 1, 'red_wine': 4, 'pecan': 3, 'ginger': 7, 'cereal': 1, 'hazelnut': 1, 'olive': 1, 'vanilla': 28, 'banana': 1, 'whiskey': 1, 'seed': 8, 'turnip': 2, 'cane_molasses': 18, 'olive_oil': 1, 'coconut':
, 'scallop': 3, 'soybean': 3, 'black_tea': 2, 'tamarind': 28, 'white_bread': 8, 'cabbage': 33, 'celery_oil': 7, 'turkey': 3, 'rutabaga': 3, 'beef': 93, 'romano_cheese': 3, 'sake': 1, 'shiitake': 1, 'anise': 22, 'caviar': 1, 'parsley': 94, 'parsnip': 4, 'scallion': 17, 'cured_pork': 1, 'buttermilk': 26, 'beer': 10, 'cogn ...

# %%
type_recipes = {}
details = []
with open('epic_recipes.txt') as f:
    for line in f:
        row = line.split('\t')
        row[len(row) - 1] = row[len(row) - 1][:-1]
        TRkey = row[0]
        row.remove(TRkey)
        if TRkey in type_recipes.keys():
            for i in range(0, len(row)):
                TRkey_i = row[i]
                if TRkey_i in tr.keys():
                    tr[TRkey_i] += 1
                else:
                    if TRkey_i not in details:
                        details.append(TRkey_i)
                    tr[TRkey_i] = 1
        else:
            tr = {}
            type_recipes[TRkey] = {}
            for i in range(0, len(row)):
                TRkey_i = row[i]
                if TRkey_i not in details:
                    details.append(TRkey_i)
                tr[TRkey_i] = 1
        type_recipes[TRkey] = tr
f.close()
print type_recipes
# Out:
# {'Vietnamese': {'peanut_oil': 1, 'lemon_juice': 1, 'brussels_sprout': 1, 'white_wine': 1, 'chicken': 12, 'milk': 1, 'cilantro': 24, 'peanut': 3, 'cayenne': 30, 'grapefruit': 1, 'radish': 3, 'orange': 1, 'mung_bean': 2, 'rice': 31, 'thai_pepper': 9, 'pumpkin': 1, 'starch': 2, 'black_pepper': 16, 'bean': 11, 'bread': 5, 'coriander': 7, 'meat': 1, 'onion': 19, 'chicken_broth': 9, 'cumin': 2, 'nutmeg': 1, 'beef_broth': 3, 'pork': 6, 'oregano': 1, 'tea': 1, 'fish': 51, 'palm': 1, 'sweet_potato': 1, 'lemongrass': 10, 'roasted_peanut': 7, 'soy_sauce': 15, 'milk_fat': 1, 'lard': 1, 'pea': 2, 'pepper': 7, 'wheat': 3, 'sesame_oil': 5, 'corn': 2, 'vinegar': 15, 'shrimp': 12, 'cinnamon': 2, 'mandarin_peel': 1, 'cucumber': 11, 'dill': 2, 'lime_juice': 30, 'tabasco_pepper': 1, 'lettuce': 9, 'soybean': 4, 'tamarind': 2, 'lime': 14, 'turkey': 1, 'beef': 13, 'sesame_seed': 1, 'shiitake': 5, 'scallion': 22, 'crab': 1, 'basil': 18, 'vegetable_oil': 31, 'roasted_beef': 2, 'butter': 5, 'green_bell_pepper': 1, 'mushroom': 3, 'shallot': 15, 'pecan': 1, 'banana': 1, 'seed': 4, 'pork_liver': 1, 'root': 2, 'cane_molasses': 9, 'olive_oil': 2, 'coconut': 3, 'squid': 1, 'ginger': 16, 'carrot': 18, 'mint': 21, 'cream': 1, 'lemon': 3, 'yeast': 1, 'bone_oil': 1, 'macaroni': 4, 'catfish': 2, 'sherry': 1, 'star_anise': 8, 'bell_pepper': 8, 'fenugreek': 2, 'papaya
 'carrot': 21, 'peanut': 3, 'mint': 35, 'cream': 18, 'lamb': 11, 'lemon': 9, 'peach': 3, 'cashew': 12, 'saffron': 6, 'chicory': 1, 'macaroni': 4, 'sesame_seed': 1, 'vegetable': 11, 'sherry': 4, 'whole_grain_wheat_flour': 5, 'leek': 1, 'zucchini': 7, 'fenugreek': 66, 'papaya': 1, 'mustard': 23, 'nut': 4, 'cardamom': 39, 'pineapple': 3, 'pear': 4, 'gelatin': 1, 'mace': 2, 'garlic': 114, 'melon': 2, 'date': 1,  ...

# %%
#Filter the most popular ingredients among all different regions/countries
most_NorthAmerican = ''
most_EastAsian = ''
most_American = ''
most_China = ''
NorthAmerican = regions['NorthAmerican']
EastAsian = regions['EastAsian']
China = countries['China']
US = countries['American']
Mvalue = 0
for NAkey in NorthAmerican.keys():
    if NorthAmerican[NAkey] > Mvalue:
        most_NorthAmerican = NAkey
        Mvalue = NorthAmerican[NAkey]      
Mvalue = 0
for EAkey in EastAsian.keys():
    if EastAsian[EAkey] > Mvalue:
        most_EastAsian = EAkey
        Mvalue = EastAsian[EAkey]
Mvalue = 0
for USkey in US.keys():
    if US[USkey] > Mvalue:
        most_American = USkey
        Mvalue = US[USkey]        
Mvalue = 0
for CNkey in China.keys():
    if China[CNkey] > Mvalue:
        most_China = CNkey
        Mvalue = China[CNkey]
  
print 'North American uses ' + most_NorthAmerican + " most and with "
print  NorthAmerican['egg']
print 'And still uses soy_sauce with: ' 
print NorthAmerican['soy_sauce']
print 
print 'East Asia use ' + most_EastAsian +" most with"
print EastAsian['soy_sauce']
print 'And still uses egg with: ' 
print EastAsian['egg']
print
print 'American use ' + most_American +" most with"
print US['egg']
print 'And still uses soy_sauce with: ' 
print US['soy_sauce']
print
print 'China use ' + most_China +" most with"
print China['soy_sauce']
print 'And still uses egg with: ' 
print China['egg']
# Out:
# North American uses egg most and with
# 14802
# And still uses soy_sauce with:
# 1498
#
# East Asia use soy_sauce most with
# 164
# And still uses egg with:
# 84
#
# American use egg most with
# 14528
# And still uses soy_sauce with:
# 1441
#
# China use soy_sauce most with
# 92
# And still uses egg with:
# 51

# %%
# sort the dataframe by alphabetical order

sorted_regions = sorted(regions)
sorted_countries = sorted(countries)
sorted_ingredients = sorted(ingredients)
sorted_details = sorted(details)
sorted_type_recipes = sorted(type_recipes)
# print sorted_regions
# print sorted_countries
# print sorted_ingredients

# print sorted_type_recipes

# %%
soysause_region = []
for region in sorted_regions:
    if 'soy_sauce' in regions[region].keys():
        val = regions[region]['soy_sauce']
        soysause_region.append(val)
    else:
        soysause_region.append(0)

# print second_max_region
# print second_max_rval
EA_NA = [sorted_regions[1]]
EA_NA.append(sorted_regions[5])
print EA_NA

SS_RE = [soysause_region[1],soysause_region[5]]
print SS_RE

fig, ax = plt.subplots(figsize = (9,9))
count = 1
XEANA = np.arange(len(EA_NA))
width = 0.1
ax.set_xticks(XEANA+width/2)
ax.set_xticklabels(EA_NA)
plt.title('Difference: East Asian vs. North American')
plt.bar(XEANA, SS_RE, color = 'b', width = width)
# Out:
# ['EastAsian', 'NorthAmerican']
# [164, 1498]
# <Container object of 2 artists>

# %%
#Plots a bar graph for all the countries and how many of their recipes use eggs. 

soysause_countries = []

for country in sorted_countries:
    if 'soy_sauce' in countries[country].keys():
        val = countries[country]['soy_sauce']
        soysause_countries.append(val)
    else:
        soysause_countries.append(0)

CN_US = [sorted_countries[0]]
CN_US.append(sorted_countries[6])
print CN_US
SS_C = [soysause_countries[0],soysause_countries[6]]
print SS_C


fig, ax = plt.subplots(figsize = (9,9))
count = 1
XCNUS = np.arange(len(CN_US))
width = 0.1
ax.set_xticks(XCNUS+width/2)
ax.set_xticklabels(CN_US)
plt.title('Difference: China vs. U.S.')
plt.bar(XCNUS, SS_C, color = 'm', width = width)
# Out:
# ['American', 'China']
# [1441, 92]
# <Container object of 2 artists>

# %%
#Plot a dendogram of Epic Ingredients Types vs. # of Ingredients
TRdf = np.zeros(shape = (len(sorted_type_recipes), len(details)))
for TRk in type_recipes.keys():
    tr = type_recipes[TRk]
    for dk in tr.keys():
        i = sorted_type_recipes.index(TRk)
        j = sorted_details.index(dk)
        TRdf[i][j] = tr[dk]

TRLink = cl_hier.linkage(TRdf, method='complete', metric='euclidean')
TR_fig = plt.figure(figsize=(12,12))
cl_hier.dendrogram(TRLink, color_threshold = 300, leaf_font_size=14)
plt.title('Dendogram: Epic Ingredients Types vs. # of Ingredients')
TR_fig.show()
print sorted_type_recipes

# As you can see, the most used epic recipt is American. Chinese is not used frequently.
# Out:
# ['African', 'American', 'Asian', 'Cajun_Creole', 'Central_SouthAmerican', 'Chinese', 'EasternEuropean_Russian', 'English_Scottish', 'French', 'German', 'Greek', 'Indian', 'Irish', 'Italian', 'Japanese', 'Jewish', 'Mediterranean', 'Mexican', 'MiddleEastern', 'Moroccan', 'Scandinavian', 'Southern_SoulFood', 'Southwestern', 'Spanish_Portuguese', 'Thai', 'Vietnamese']

# %%
#Plot a dendogram of Countries vs. # of Ingredients Usage

Countriesdf = np.zeros(shape =(len(sorted_countries), len(ingredients)))
for Ck in countries.keys():
    country = countries[Ck]
    for key in country.keys():
        i = sorted_countries.index(Ck)
        j = sorted_ingredients.index(key)
        Countriesdf[i][j] = country[key]
        
        
CLink = cl_hier.linkage(Countriesdf, method='complete', metric='euclidean')
C_fig = plt.figure(figsize=(15,15))
cl_hier.dendrogram(CLink, color_threshold = 300, leaf_font_size=14)
plt.title('Dendogram:  Countries vs. # of Ingredients Usage')

C_fig.show()

# As you can see from the first list, American is 0 and China is 6

# %%
# Short (datailed) analysis of specific cluster

# Please see the pdf file uploaded

# %% [markdown]
# ### References

# %% [markdown]
# 1. Ahn, Yong-Yeol, et al. "Flavor network and the principles of food pairing." Scientific reports 1 (2011).

# %%
# Code for setting the style of the notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("../../theme/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=EB+Garamond' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     .code_cell {
#         width: 105ex !important ;
#         margin-bottom: 15px !important;
#     }
#     div.cell {
#         margin-left: auto;
#         margin-right: auto;
#         width: 70%;
#     }
#     div.cell.selected {
#         border: thin rgba(171, 171, 171, 0.5) dashed;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
#         font-family: 'EB Garamond', serif;
#     }
#     h3 {
#         font-family: 'EB Garamond', serif;
#         margin-top:12px;
#         margin-bottom: 3px;
#     }
#     h4 {
#         font-family: 'EB Garamond', serif;
#     }
#     h5 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     div.text_cell_render {
#         font-family: 'EB Garamond',Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 140%;
#     }
#     div.input_area {
#         border-color: rgba(0,0,0,0.10) !important;
#         background: #fafafa;
#     }
#     .CodeMirror {
#             font-family: "Source Code Pro";
#             font-size: 90%;
#     }
#     .prompt {
#         display: None;
#     }
#     .output {
#         padding-left: 50px;
#         padding-top: 5px;
#     }
#     .output_wrapper {
#         padding-left: 5px;
#         padding-top: inherit;
#     }
#     div.output_scroll {
#         width: inherit;
#     }
#     .inner_cell {
#         padding-left: 5px;
#     }
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 50pt;
#         line-height: 100%;
#         color:#CD2305;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #CD2305;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .warning {
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
